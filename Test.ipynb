# %% [markdown]
# # Download Raw Data

# %%
import os
import urllib.request
import zipfile
from pathlib import Path
from tqdm import tqdm

# %%
class DownloadProgressBar(tqdm):
    """Custom progress bar for download progress"""
    def update_to(self, b=1, bsize=1, tsize=None):
        if tsize is not None:
            self.total = tsize
        self.update(b * bsize - self.n)

# %%
def download_and_extract_godot_docs():
    """
    Download and extract Godot documentation from the nightly build.
    """
    # Create data/raw directory if it doesn't exist
    data_dir = Path("data/raw")
    data_dir.mkdir(parents=True, exist_ok=True)
    
    # URL for the Godot docs zip file
    docs_url = "https://nightly.link/godotengine/godot-docs/workflows/build_offline_docs/master/godot-docs-html-stable.zip"
    zip_filename = data_dir / "godot-docs-html-stable.zip"
    
    print(f"Downloading Godot documentation from: {docs_url}")
    print(f"Saving to: {zip_filename}")
    
    try:
        # Download the zip file with progress bar
        print("📥 Starting download...")
        with DownloadProgressBar(unit='B', unit_scale=True, miniters=1, desc="Downloading") as t:
            urllib.request.urlretrieve(docs_url, zip_filename, reporthook=t.update_to)
        print(f"✅ Download completed: {zip_filename}")
        
        # Extract the zip file with progress bar
        print(f"📦 Extracting {zip_filename}...")
        with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
            # Get list of files to extract
            file_list = zip_ref.namelist()
            
            # Extract with progress bar
            with tqdm(total=len(file_list), desc="Extracting", unit="files") as pbar:
                for file in file_list:
                    zip_ref.extract(file, data_dir)
                    pbar.update(1)
        
        print(f"✅ Extraction completed to: {data_dir}")
        
        # Optional: Remove the zip file after extraction
        print("🧹 Cleaning up...")
        os.remove(zip_filename)
        print("✅ Zip file removed after extraction")
        
        # List the contents of the data/raw directory
        print("\nContents of data/raw directory:")
        for item in data_dir.iterdir():
            if item.is_dir():
                print(f"  📁 {item.name}/")
            else:
                print(f"  📄 {item.name}")
                
    except Exception as e:
        print(f"Error downloading or extracting documentation: {e}")
        return False
    
    return True

# %%
success = download_and_extract_godot_docs()
if success:
     print("\n✅ Godot documentation download and extraction completed successfully!")
else:
     print("\n❌ Failed to download and extract Godot documentation.")
# Out:
# Downloading Godot documentation from: https://nightly.link/godotengine/godot-docs/workflows/build_offline_docs/master/godot-docs-html-stable.zip
# Saving to: data/raw/godot-docs-html-stable.zip
# 📥 Starting download...
# Downloading: 361MB [00:23, 15.4MB/s]
# ✅ Download completed: data/raw/godot-docs-html-stable.zip
# 📦 Extracting data/raw/godot-docs-html-stable.zip...
# Extracting: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4808/4808 [00:03<00:00, 1378.88files/s]
# ✅ Extraction completed to: data/raw
# 🧹 Cleaning up...
# ✅ Zip file removed after extraction
#
# Contents of data/raw directory:
#   📄 index.html
#   📁 classes/
#   📁 getting_started/
#   📄 objects.inv
#   📄 404.html
#   📁 tutorials/
#   📄 searchindex.js
#   📁 community/
#   📁 about/
#   📄 robots.txt
#   📄 genindex.html
#   📁 _downloads/
#   📁 _images/
#   📁 contributing/
#   📄 search.html
#   📁 _static/
#   📁 _sources/
#
# ✅ Godot documentation download and extraction completed successfully!

# %% [markdown]
# # Load HTML with Unstructured

# %%
import os
from pathlib import Path
from typing import List
from langchain_community.document_loaders import UnstructuredHTMLLoader, BSHTMLLoader
from langchain.schema import Document
from tqdm import tqdm
import glob


def find_html_files(directory: str) -> List[str]:
    """
    Find all HTML files in the given directory and subdirectories.
    
    Args:
        directory (str): The directory to search for HTML files
        
    Returns:
        List[str]: List of paths to HTML files
    """
    html_files = []
    
    # Use glob to find all HTML files recursively
    pattern = os.path.join(directory, "**", "*.html")
    html_files = glob.glob(pattern, recursive=True)
    
    return html_files

# %%
import os
from pathlib import Path
from typing import List
from langchain_community.document_loaders import UnstructuredHTMLLoader, BSHTMLLoader
from langchain.schema import Document
from tqdm import tqdm
import glob

def load_html_with_unstructured(file_paths: List[str]) -> List[Document]:
    """
    Load HTML files using UnstructuredHTMLLoader.
    
    Args:
        file_paths (List[str]): List of HTML file paths
        
    Returns:
        List[Document]: List of LangChain Document objects
    """
    documents = []
    
    print("📄 Loading HTML files with Unstructured...")
    
    for file_path in tqdm(file_paths, desc="Processing with Unstructured"):
        try:
            loader = UnstructuredHTMLLoader(file_path)
            docs = loader.load()
            documents.extend(docs)
        except Exception as e:
            print(f"❌ Error loading {file_path} with Unstructured: {e}")
            continue
    
    return documents

# %%
import os
from pathlib import Path
from typing import List
from langchain_community.document_loaders import UnstructuredHTMLLoader, BSHTMLLoader
from langchain.schema import Document
from tqdm import tqdm
import glob

docs_dir = "data/raw"
documents = []

html_files = find_html_files(docs_dir)

documents = load_html_with_unstructured(html_files)

print(f"✅ Successfully loaded {len(documents)} documents")
# Out:
# 📄 Loading HTML files with Unstructured...
# Processing with Unstructured:   0%|                                                                                                                                    | 0/1490 [00:00<?, ?it/s]
# Processing with Unstructured:  57%|█████████████████████████████████████████████████████████████████████▊                                                    | 852/1490 [01:14<00:52, 12.19it/s]short text: "All classes". Defaulting to English.
# short text: "TextServerExtension". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Removes all kerning overrides.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Returns font anti-aliasing mode.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Returns font embolden strength.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Returns font family name.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Returns font style name.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Remove language support override.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Removes script support override.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Sets font anti-aliasing mode.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Adds override for _font_is_language_supported().". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Adds override for _font_is_script_supported().". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Returns text span metadata.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Returns text orientation.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Sets desired text orientation.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Required.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Optional.". Defaulting to English.
# short text: "Previous Next". Defaulting to English.
# Processing with Unstructured:  58%|██████████████████████████████████████████████████████████████████████▋                                                   | 863/1490 [01:16<01:16,  8.18it/s]short text: "All classes". Defaulting to English.
# short text: "VisualShaderNodeIntParameter". Defaulting to English.
# short text: "Hint HINT_NONE = 0". Defaulting to English.
# short text: "Hint HINT_RANGE = 1". Defaulting to English.
# short text: "Hint HINT_RANGE_STEP = 2". Defaulting to English.
# short text: "Hint HINT_ENUM = 3". Defaulting to English.
# short text: "Hint HINT_MAX = 4". Defaulting to English.
# short text: "void set_default_value(value: int)". Defaulting to English.
# short text: "int get_default_value()". Defaulting to English.
# short text: "void set_default_value_enabled(value: bool)". Defaulting to English.
# short text: "bool is_default_value_enabled()". Defaulting to English.
# short text: "void set_enum_names(value: PackedStringArray)". Defaulting to English.
# short text: "PackedStringArray get_enum_names()". Defaulting to English.
# short text: "void set_hint(value: Hint)". Defaulting to English.
# short text: "Hint get_hint()". Defaulting to English.
# short text: "void set_max(value: int)". Defaulting to English.
# short text: "int get_max()". Defaulting to English.
# short text: "void set_min(value: int)". Defaulting to English.
# short text: "int get_min()". Defaulting to English.
# short text: "void set_step(value: int)". Defaulting to English.
# short text: "int get_step()". Defaulting to English.
# short text: "Previous Next". Defaulting to English.
# Processing with Unstructured:  72%|██████████████████████████████████████████████████████████████████████████████████████▌                                  | 1066/1490 [01:32<00:30, 13.90it/s]short text: "Internationalization". Defaulting to English.
# short text: "Locale codes". Defaulting to English.
# short text: "Edit on GitHub". Defaulting to English.
# short text: "Learn how to contribute!". Defaulting to English.
# short text: "Previous Next". Defaulting to English.
# Processing with Unstructured:  79%|███████████████████████████████████████████████████████████████████████████████████████████████                          | 1171/1490 [01:39<00:29, 10.96it/s]short text: "3D". Defaulting to English.
# short text: "Environment and post-processing". Defaulting to English.
# short text: "Edit on GitHub". Defaulting to English.
# short text: "Learn how to contribute!". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_camera.webp". Defaulting to English.
# short text: "../../_images/environment_world.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_preview_sun_sky_toggle.webp". Defaulting to English.
# short text: "../../_images/environment_preview_sun_sky_dialog.webp". Defaulting to English.
# short text: "Tip". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_background1.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_ambient2.webp". Defaulting to English.
# short text: "../../_images/environment_ambient_comparison.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_fog_depth_height.webp". Defaulting to English.
# short text: "../../_images/environment_fog_transmission.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "See also". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_ssr.webp". Defaulting to English.
# short text: "../../_images/environment_ssao.webp". Defaulting to English.
# short text: "../../_images/environment_ssao2.webp". Defaulting to English.
# short text: "../../_images/environment_ssao_parameters.webp". Defaulting to English.
# short text: "../../_images/environment_ssil.webp". Defaulting to English.
# short text: "See also". Defaulting to English.
# short text: "../../_images/environment_sdfgi.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_glow1.webp". Defaulting to English.
# short text: "../../_images/environment_glow_threshold.webp". Defaulting to English.
# short text: "../../_images/environment_glow_bloom.webp". Defaulting to English.
# short text: "../../_images/environment_glow_layers.webp". Defaulting to English.
# short text: "../../_images/environment_glow_layers2.webp". Defaulting to English.
# short text: "../../_images/environment_glow_map.webp". Defaulting to English.
# short text: "../../_images/environment_and_post_processing_glow_scale_mode.webp". Defaulting to English.
# short text: "Warning". Defaulting to English.
# short text: "../../_images/environment_adjustments.webp". Defaulting to English.
# short text: "Basic BCS adjustments". Defaulting to English.
# short text: "../../_images/environment_adjustments_bcs.webp". Defaulting to English.
# short text: "../../_images/environment_adjustments_default_gradient.webp". Defaulting to English.
# short text: "../../_images/environment_adjustments_custom_gradient.webp". Defaulting to English.
# short text: "../../_images/environment_adjustments_3d_lut_import.webp". Defaulting to English.
# short text: "../../_images/environment_adjustments_3d_lut_template.webp". Defaulting to English.
# short text: "../../_images/environment_adjustments_3d_lut_comparison.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_dof_far.webp". Defaulting to English.
# short text: "../../_images/environment_dof_near.webp". Defaulting to English.
# short text: "../../_images/environment_mixed_blur.webp". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "Note". Defaulting to English.
# short text: "../../_images/environment_hdr_autoexp.webp". Defaulting to English.
# short text: "../../_images/environment_hdr_bloom.webp". Defaulting to English.
# short text: "../../_images/environment_hdr.webp". Defaulting to English.
# short text: "See also". Defaulting to English.
# short text: "Previous Next". Defaulting to English.
# Processing with Unstructured: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1490/1490 [02:04<00:00, 11.98it/s]
# ✅ Successfully loaded 1490 documents
